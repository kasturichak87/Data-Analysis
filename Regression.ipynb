# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.array([0,1,2,3,4,5])
y = np.array([0,0.6,0.8,0.9,-0.8,-0.4])

print(x)
print(y)
# Out:
# [0 1 2 3 4 5]
# [ 0.   0.6  0.8  0.9 -0.8 -0.4]

# %%
p1 = sp.polyfit(x,y,1)
print(p1)
# Out:
# [-0.17428571  0.61904762]

# %%
plt.plot(x,y,'o')

# %%
plt.plot(x,y,'o')

plt.plot(x,np.polyval(p1,x),'r-')
plt.plot(x,np.polyval(p2,x),'g-')
plt.plot(x,np.polyval(p3,x),'b--')
p2 =sp.polyfit(x,y,2)

p3 =sp. polyfit(x,y,3)

print (p2)
print(p3)
# Out:
# [-0.15357143  0.59357143  0.10714286]
# [ 0.06851852 -0.66746032  1.53227513 -0.0984127 ]
